# %%
import gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 7]

from IPython.display import clear_output
from time import sleep

# %%
class TaxiEnv:

    def __init__(self, method, alpha, temperature, env, gamma):
        self.env = env
        self.method = method
        self.positions = 25
        self.num_ps_location = 5
        self.num_ps_destination = 4
        self.num_states = self.positions * self.num_ps_location * self.num_ps_destination
        self.num_actions = 6
        self.alpha = alpha
        self.gamma = gamma
        self.temperature = temperature
        # initialize q table
        self.q = np.zeros(shape=(self.num_states, self.num_actions))
        # initialize policy
        self.pi = np.zeros_like(self.q)

    def interact(self):
        state = self.env.reset()
        delivered = False
        r_sum = 0
        steps = 0
        while not delivered:
            steps += 1
            action, probs = self._take_action(state)
            next_state, reward, delivered, info = self.env.step(action)

            if self.method == 'sarsa':
                next_action = self._take_action(next_state)[0]
                self.q[state][action] += self.alpha * \
                                         (reward + self.gamma * self.q[next_state][next_action] - self.q[state][action])
            elif self.method == 'q_learning':
                next_action = np.random.choice(np.where(self.q[next_state] == max(self.q[next_state]))[0])
                self.q[state][action] += self.alpha * \
                                         (reward + self.gamma * self.q[next_state][next_action] - self.q[state][action])
            elif self.method == 'expected_sarsa':
                self.q[state][action] += self.alpha * (reward + self.gamma * np.dot(probs, self.q[state])
                                                       - self.q[state][action])

            r_sum += reward
            state = next_state
        return r_sum

    def _take_action(self, state):
        self.pi[state] = np.exp(self.q[state] / self.temperature)
        prob = np.true_divide(self.pi[state], sum(self.pi[state]))
        a = np.random.choice(np.arange(6), p=prob)
        return a, prob

    def run_optimal_policy(self):
        state = self.env.reset()
        delivered = False
        r_sum = 0
        steps = 0
        while delivered == False:
            steps += 1
            action = np.random.choice(np.where(self.q[state] == max(self.q[state]))[0])
            next_state, reward, delivered, info = self.env.step(action)
            r_sum += reward
            state = next_state

            if delivered:
                print(end="")

        return r_sum

    def train(self, print_trace=False):
        runs = 10
        segments = 100
        episodes = 10

        train_rewards = []
        test_rewards = []

        reward_train_episodes = []
        reward_test_episode = []
        all_test_rewards = np.zeros(shape=(runs, segments))

        for run in range(runs):
            self.q = np.zeros(shape=(self.num_states, self.num_actions))
            for segment in range(segments):
                train_rewards = []
                for episode in range(episodes + 1):
                    if episode < episodes:
                        reward_sum = self.interact()
                        train_rewards.append(reward_sum)
                    else:
                        test_reward = self.run_optimal_policy()
                        test_rewards.append(test_reward)
                    if print_trace:
                        if episode == episodes:
                            all_test_rewards[run][segment] = test_rewards[-1]
                            if segment % 10 == 0 or segment == 99:
                                print('{} | alpha {}, tau {:3.2f} | Run {:2d}, Segment {:2d}'.
                                      format(self.method, self.alpha, self.temperature, run, segment), end=" ")
                                print('| train reward {:8.2f}, test_reward {}'.
                                      format(np.mean(train_rewards[episode - 10:episode]), test_rewards[-1]))
                    if episode == episodes and segment == segments - 1:  # last segment, last episode
                        reward_train_episodes.append(np.mean(train_rewards))
                        reward_test_episode.append(test_rewards[-1])

        train_per_run = np.mean(reward_train_episodes)    # for the first bullet in the question
        test_per_run = np.mean(reward_test_episode)       # for the second bullet in the question
        avg_test_reward_per_run = np.mean(all_test_rewards, axis=0)  # for the third bullet in the question
        std_test_reward_per_run = np.std(all_test_rewards, axis=0)   # for the third bullet in the question

        return train_per_run, test_per_run, avg_test_reward_per_run, std_test_reward_per_run

# %%
env = gym.make('Taxi-v2')

learning_rates = [0.3, 0.5, 0.8]
temperatures = [0.5, 1, 1.5]

# %%
def plot_graph(x_value, y_values, legend_names, x_axis_title, y_axis_title, filename_to_save):
    fig = plt.figure(1)
    ax = fig.add_subplot(1, 1, 1)
    for i in range(len(y_values)):
        ax.plot(x_value,
                y_values[i],
                label=legend_names[i])
    ax.set_xlabel(x_axis_title)
    ax.set_ylabel(y_axis_title)

    plt.legend(loc='upper left')
#     if saveFigures:
#         plt.savefig(filename_to_save)
#     if plot_graph_:
    plt.show()
    plt.clf()

# %%
def plot_error(x, y, e, alpha, tau):
    fig, ax = plt.subplots()
    ax.errorbar(x, y, e,  linestyle='solid', marker='o')
    ax.set_title('Learning curve for alpha {} - tau {}'.format(alpha, tau))
    ax.set_xlabel('Segments')
    ax.set_ylabel('Mean and Std test rewards')
    plt.show()

# %%
agents = ['sarsa']
for agent in agents:
    agent_train_rewards = np.zeros(shape=(len(temperatures), len(learning_rates)))
    agent_test_rewards = np.zeros_like(agent_train_rewards)
    for temp in temperatures:
        for learning_rate in learning_rates:
            agent_object = TaxiEnv(agent, learning_rate, temp, env, gamma=0.9)
            train_rewards, test_rewards, avg_test, std_test = agent_object.train(print_trace=True)
            agent_train_rewards[temperatures.index(temp)][learning_rates.index(learning_rate)] = train_rewards
            agent_test_rewards[temperatures.index(temp)][learning_rates.index(learning_rate)] = test_rewards
            
            plot_error(np.arange(100), avg_test, std_test)
# Out:
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment  0 | train reward  -463.90, test_reward -749
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment 10 | train reward  -170.50, test_reward -200
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment 20 | train reward   -80.00, test_reward 11
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment 30 | train reward   -39.40, test_reward -200
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment 40 | train reward   -32.50, test_reward -200
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment 50 | train reward     7.30, test_reward -200
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment 60 | train reward     7.50, test_reward -200
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment 70 | train reward    -3.00, test_reward -200
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment 80 | train reward     4.20, test_reward 9
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment 90 | train reward     8.40, test_reward 6
# sarsa | alpha 0.3, tau 0.50 | Run  0, Segment 99 | train reward     8.20, test_reward 3
# sarsa | alpha 0.3, tau 0.50 | Run  1, Segment  0 | train reward  -437.10, test_reward -200
# sarsa | alpha 0.3, tau 0.50 | Run  1, Segment 10 | train reward  -209.50, test_reward -200
# sarsa | alpha 0.3, tau 0.50 | Run  1, Segment 20 | train reward   -79.70, test_reward -200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-30186e6d2d47> in <module>
#       6         for learning_rate in learning_rates:
#       7             agent_object = TaxiEnv(agent, learning_rate, temp, env, gamma=0.9)
# ----> 8             train_rewards, test_rewards, avg_test, std_test = agent_object.train(print_trace=True)
#       9             agent_train_rewards[temperatures.index(temp)][learning_rates.index(learning_rate)] = train_rewards
#      10             agent_test_rewards[temperatures.index(temp)][learning_rates.index(learning_rate)] = test_rewards
#
# <ipython-input-2-50173192d73d> in train(self, print_trace)
#      84                 for episode in range(episodes + 1):
#      85                     if episode < episodes:
# ---> 86                         reward_sum = self.interact()
#      87                         train_rewards.append(reward_sum)
#      88                     else:
#
# <ipython-input-2-50173192d73d> in interact(self)
#      25             steps += 1
#      26             action, probs = self._take_action(state)
# ---> 27             next_state, reward, delivered, info = self.env.step(action)
#      28
#      29             if self.method == 'sarsa':
#
# ~\Anaconda3\lib\site-packages\gym\wrappers\time_limit.py in step(self, action)
#      29     def step(self, action):
#      30         assert self._episode_started_at is not None, "Cannot call env.step() before calling reset()"
# ---> 31         observation, reward, done, info = self.env.step(action)
#      32         self._elapsed_steps += 1
#      33
#
# ~\Anaconda3\lib\site-packages\gym\envs\toy_text\discrete.py in step(self, a)
#      54     def step(self, a):
#      55         transitions = self.P[self.s][a]
# ---> 56         i = categorical_sample([t[0] for t in transitions], self.np_random)
#      57         p, s, r, d= transitions[i]
#      58         self.s = s
#
# ~\Anaconda3\lib\site-packages\gym\envs\toy_text\discrete.py in categorical_sample(prob_n, np_random)
#      11     prob_n = np.asarray(prob_n)
#      12     csprob_n = np.cumsum(prob_n)
# ---> 13     return (csprob_n > np_random.rand()).argmax()
#      14
#      15
#
# KeyboardInterrupt:

# %%
# plots for 'sarsa' training and test
plot_graph(learning_rates, agent_train_rewards, temperatures, 'learning rate',
           'Av. return during testing ('+agent+')', 'av_return_l_rate_testing_'+agent+'.png')
plot_graph(learning_rates, agent_test_rewards, temperatures, 'learning rate',
           'Av. return during testing ('+agent+')', 'av_return_l_rate_testing_'+agent+'.png')

# %%
agents = ['q_learning']
for agent in agents:
    agent_train_rewards = np.zeros(shape=(len(temperatures), len(learning_rates)))
    agent_test_rewards = np.zeros_like(agent_train_rewards)
    for temp in temperatures:
        for learning_rate in learning_rates:
            agent_object = TaxiEnv(agent, learning_rate, temp, env, gamma=0.9)
            train_rewards, test_rewards, avg_test, std_test = agent_object.train(print_trace=True)
            agent_train_rewards[temperatures.index(temp)][learning_rates.index(learning_rate)] = train_rewards
            agent_test_rewards[temperatures.index(temp)][learning_rates.index(learning_rate)] = test_rewards
# Out:
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment  0 | train reward  -480.80, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment 10 | train reward  -200.60, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment 20 | train reward   -88.70, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment 30 | train reward   -65.10, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment 40 | train reward   -14.30, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment 50 | train reward     0.90, test_reward 11
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment 60 | train reward     2.90, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment 70 | train reward     2.80, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment 80 | train reward     7.50, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment 90 | train reward     5.80, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  0, Segment 99 | train reward     6.50, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment  0 | train reward  -411.60, test_reward -1973
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment 10 | train reward  -177.40, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment 20 | train reward  -109.10, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment 30 | train reward   -26.30, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment 40 | train reward   -22.20, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment 50 | train reward    -5.70, test_reward 5
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment 60 | train reward     2.00, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment 70 | train reward     8.20, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment 80 | train reward     6.00, test_reward 12
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment 90 | train reward     7.90, test_reward 10
# q_learning | alpha 0.3, tau 0.50 | Run  1, Segment 99 | train reward     7.50, test_reward 7
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment  0 | train reward  -486.30, test_reward -1037
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment 10 | train reward  -215.20, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment 20 | train reward  -101.00, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment 30 | train reward   -61.70, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment 40 | train reward   -13.70, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment 50 | train reward    -2.70, test_reward 7
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment 60 | train reward     4.40, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment 70 | train reward     3.80, test_reward 6
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment 80 | train reward     3.90, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment 90 | train reward     7.60, test_reward 7
# q_learning | alpha 0.3, tau 0.50 | Run  2, Segment 99 | train reward     8.40, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment  0 | train reward  -492.50, test_reward -848
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment 10 | train reward  -158.30, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment 20 | train reward  -143.40, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment 30 | train reward   -18.10, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment 40 | train reward   -21.00, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment 50 | train reward     0.00, test_reward 12
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment 60 | train reward    -0.20, test_reward 12
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment 70 | train reward     8.00, test_reward 12
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment 80 | train reward     1.60, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment 90 | train reward     6.80, test_reward 11
# q_learning | alpha 0.3, tau 0.50 | Run  3, Segment 99 | train reward     5.80, test_reward 11
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment  0 | train reward  -479.00, test_reward -812
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment 10 | train reward  -177.30, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment 20 | train reward  -104.50, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment 30 | train reward   -35.40, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment 40 | train reward    -9.00, test_reward 6
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment 50 | train reward     1.20, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment 60 | train reward    -3.50, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment 70 | train reward     6.60, test_reward 12
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment 80 | train reward     4.00, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment 90 | train reward     7.20, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  4, Segment 99 | train reward     8.40, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment  0 | train reward  -465.60, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment 10 | train reward  -209.20, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment 20 | train reward   -49.80, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment 30 | train reward   -55.80, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment 40 | train reward   -10.50, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment 50 | train reward    -9.50, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment 60 | train reward     0.00, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment 70 | train reward     9.40, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment 80 | train reward     2.80, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment 90 | train reward     7.50, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  5, Segment 99 | train reward     8.10, test_reward 11
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment  0 | train reward  -499.80, test_reward -236
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment 10 | train reward  -205.90, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment 20 | train reward   -45.30, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment 30 | train reward   -86.20, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment 40 | train reward    -0.80, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment 50 | train reward    -3.70, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment 60 | train reward     4.40, test_reward 15
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment 70 | train reward     2.10, test_reward 10
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment 80 | train reward     5.10, test_reward 10
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment 90 | train reward     6.30, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  6, Segment 99 | train reward     7.50, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment  0 | train reward  -477.20, test_reward -2000
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment 10 | train reward  -204.30, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment 20 | train reward   -35.50, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment 30 | train reward   -37.10, test_reward 11
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment 40 | train reward    -9.80, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment 50 | train reward    -5.50, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment 60 | train reward    -1.20, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment 70 | train reward     1.90, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment 80 | train reward     9.30, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment 90 | train reward     7.70, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  7, Segment 99 | train reward     7.00, test_reward 5
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment  0 | train reward  -424.90, test_reward -803
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment 10 | train reward  -164.20, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment 20 | train reward   -85.30, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment 30 | train reward   -53.60, test_reward 10
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment 40 | train reward   -36.70, test_reward 11
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment 50 | train reward    -1.90, test_reward 12
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment 60 | train reward     6.30, test_reward 6
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment 70 | train reward     6.20, test_reward 5
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment 80 | train reward     4.60, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment 90 | train reward     6.20, test_reward 5
# q_learning | alpha 0.3, tau 0.50 | Run  8, Segment 99 | train reward     8.70, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment  0 | train reward  -376.10, test_reward -713
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment 10 | train reward  -220.00, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment 20 | train reward   -77.40, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment 30 | train reward   -59.00, test_reward -200
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment 40 | train reward   -33.50, test_reward 8
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment 50 | train reward   -11.50, test_reward 6
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment 60 | train reward     7.10, test_reward 7
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment 70 | train reward     5.10, test_reward 9
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment 80 | train reward     2.40, test_reward 6
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment 90 | train reward     5.40, test_reward 10
# q_learning | alpha 0.3, tau 0.50 | Run  9, Segment 99 | train reward     7.80, test_reward 5
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment  0 | train reward  -471.00, test_reward -884
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment 10 | train reward  -108.60, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment 20 | train reward   -32.90, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment 30 | train reward   -18.20, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment 40 | train reward    -2.80, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment 50 | train reward     1.40, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment 60 | train reward     6.10, test_reward 5
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment 70 | train reward     6.90, test_reward 8
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment 80 | train reward     8.30, test_reward 5
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment 90 | train reward     8.70, test_reward 10
# q_learning | alpha 0.5, tau 0.50 | Run  0, Segment 99 | train reward     7.20, test_reward 8
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment  0 | train reward  -500.20, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment 10 | train reward  -120.00, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment 20 | train reward   -34.60, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment 30 | train reward    -4.80, test_reward 8
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment 40 | train reward     7.70, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment 50 | train reward     8.30, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment 60 | train reward     7.40, test_reward 10
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment 70 | train reward     8.20, test_reward 6
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment 80 | train reward     6.30, test_reward 10
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment 90 | train reward     6.10, test_reward 12
# q_learning | alpha 0.5, tau 0.50 | Run  1, Segment 99 | train reward     8.00, test_reward 6
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment  0 | train reward  -507.80, test_reward -776
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment 10 | train reward  -158.70, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment 20 | train reward   -18.90, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment 30 | train reward    -5.80, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment 40 | train reward     4.20, test_reward 9
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment 50 | train reward     3.20, test_reward 9
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment 60 | train reward     5.50, test_reward 5
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment 70 | train reward     7.90, test_reward 9
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment 80 | train reward     7.60, test_reward 6
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment 90 | train reward     6.30, test_reward 9
# q_learning | alpha 0.5, tau 0.50 | Run  2, Segment 99 | train reward     8.70, test_reward 8
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment  0 | train reward  -477.40, test_reward -749
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment 10 | train reward  -116.00, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment 20 | train reward   -18.80, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment 30 | train reward    -7.20, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment 40 | train reward    -2.20, test_reward 10
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment 50 | train reward     4.80, test_reward 8
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment 60 | train reward     5.00, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment 70 | train reward     6.00, test_reward 9
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment 80 | train reward     8.00, test_reward 9
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment 90 | train reward     7.50, test_reward 11
# q_learning | alpha 0.5, tau 0.50 | Run  3, Segment 99 | train reward     7.50, test_reward 7
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment  0 | train reward  -508.70, test_reward -641
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment 10 | train reward  -177.70, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment 20 | train reward   -36.70, test_reward 10
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment 30 | train reward   -11.20, test_reward 10
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment 40 | train reward     4.20, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment 50 | train reward     7.50, test_reward 13
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment 60 | train reward     9.60, test_reward 6
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment 70 | train reward     3.80, test_reward 9
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment 80 | train reward     6.90, test_reward 6
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment 90 | train reward     6.60, test_reward 4
# q_learning | alpha 0.5, tau 0.50 | Run  4, Segment 99 | train reward     8.70, test_reward 5
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment  0 | train reward  -463.70, test_reward -713
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment 10 | train reward   -94.70, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment 20 | train reward   -28.30, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment 30 | train reward    -6.00, test_reward 8
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment 40 | train reward     1.10, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment 50 | train reward     5.70, test_reward 6
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment 60 | train reward     6.20, test_reward 15
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment 70 | train reward     4.50, test_reward 5
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment 80 | train reward     7.70, test_reward 6
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment 90 | train reward     6.70, test_reward 5
# q_learning | alpha 0.5, tau 0.50 | Run  5, Segment 99 | train reward     8.20, test_reward 5
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment  0 | train reward  -463.20, test_reward -1046
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment 10 | train reward  -185.80, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment 20 | train reward   -62.40, test_reward 13
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment 30 | train reward   -12.30, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment 40 | train reward     6.10, test_reward 8
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment 50 | train reward     8.90, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment 60 | train reward     7.40, test_reward 8
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment 70 | train reward     9.30, test_reward 6
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment 80 | train reward     6.70, test_reward 11
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment 90 | train reward     7.60, test_reward 10
# q_learning | alpha 0.5, tau 0.50 | Run  6, Segment 99 | train reward     8.10, test_reward 9
# q_learning | alpha 0.5, tau 0.50 | Run  7, Segment  0 | train reward  -469.20, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  7, Segment 10 | train reward  -114.20, test_reward -200
# q_learning | alpha 0.5, tau 0.50 | Run  7, Segment 20 | train reward   -33.70, test_reward -200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-7e47dda238fb> in <module>
#       6         for learning_rate in learning_rates:
#       7             agent_object = TaxiEnv(agent, learning_rate, temp, env, gamma=0.9)
# ----> 8             train_rewards, test_rewards, avg_test, std_test = agent_object.train(print_trace=True)
#       9             agent_train_rewards[temperatures.index(temp)][learning_rates.index(learning_rate)] = train_rewards
#      10             agent_test_rewards[temperatures.index(temp)][learning_rates.index(learning_rate)] = test_rewards
#
# <ipython-input-2-50173192d73d> in train(self, print_trace)
#      87                         train_rewards.append(reward_sum)
#      88                     else:
# ---> 89                         test_reward = self.run_optimal_policy()
#      90                         test_rewards.append(test_reward)
#      91                     if print_trace:
#
# <ipython-input-2-50173192d73d> in run_optimal_policy(self)
#      57             steps += 1
#      58             action = np.random.choice(np.where(self.q[state] == max(self.q[state]))[0])
# ---> 59             next_state, reward, delivered, info = self.env.step(action)
#      60             r_sum += reward
#      61             state = next_state
#
# ~\Anaconda3\lib\site-packages\gym\wrappers\time_limit.py in step(self, action)
#      29     def step(self, action):
#      30         assert self._episode_started_at is not None, "Cannot call env.step() before calling reset()"
# ---> 31         observation, reward, done, info = self.env.step(action)
#      32         self._elapsed_steps += 1
#      33
#
# ~\Anaconda3\lib\site-packages\gym\envs\toy_text\discrete.py in step(self, a)
#      54     def step(self, a):
#      55         transitions = self.P[self.s][a]
# ---> 56         i = categorical_sample([t[0] for t in transitions], self.np_random)
#      57         p, s, r, d= transitions[i]
#      58         self.s = s
#
# ~\Anaconda3\lib\site-packages\gym\envs\toy_text\discrete.py in categorical_sample(prob_n, np_random)
#      11     prob_n = np.asarray(prob_n)
#      12     csprob_n = np.cumsum(prob_n)
# ---> 13     return (csprob_n > np_random.rand()).argmax()
#      14
#      15
#
# KeyboardInterrupt:

# %%
# plots for 'q_learning' training and test
plot_graph(learning_rates, agent_train_rewards, temperatures, 'learning rate',
           'Av. return during testing ('+agent+')', 'av_return_l_rate_testing_'+agent+'.png')
plot_graph(learning_rates, agent_test_rewards, temperatures, 'learning rate',
           'Av. return during testing ('+agent+')', 'av_return_l_rate_testing_'+agent+'.png')
plot_error(np.arange(100), avg_test, std_test)

# %%
agents = ['expected_sarsa']
for agent in agents:
    agent_train_rewards = np.zeros(shape=(len(temperatures), len(learning_rates)))
    agent_test_rewards = np.zeros_like(agent_train_rewards)
    for temp in temperatures:
        for learning_rate in learning_rates:
            agent_object = TaxiEnv(agent, learning_rate, temp, env, gamma=0.9)
            train_rewards, test_rewards, avg_test, std_test = agent_object.train(print_trace=True)
            agent_train_rewards[temperatures.index(temp)][learning_rates.index(learning_rate)] = train_rewards
            agent_test_rewards[temperatures.index(temp)][learning_rates.index(learning_rate)] = test_rewards

# %%
# plots for 'expected_sarsa' training and test
plot_graph(learning_rates, agent_train_rewards, temperatures, 'learning rate',
           'Av. return during testing ('+agent+')', 'av_return_l_rate_testing_'+agent+'.png')
plot_graph(learning_rates, agent_test_rewards, temperatures, 'learning rate',
           'Av. return during testing ('+agent+')', 'av_return_l_rate_testing_'+agent+'.png')
plot_error(np.arange(100), avg_test, std_test)
